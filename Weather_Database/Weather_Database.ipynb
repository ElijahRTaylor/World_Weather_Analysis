# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
import requests

# Import the API key.
from config import weather_api_key

import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description= city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rawson
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | komsomolskiy
# Processing Record 4 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 1 | west wendover
# Processing Record 6 of Set 1 | zemio
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | beringovskiy
# Processing Record 9 of Set 1 | skibbereen
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | vincennes
# Processing Record 12 of Set 1 | mount isa
# Processing Record 13 of Set 1 | ardakan
# Processing Record 14 of Set 1 | port keats
# Processing Record 15 of Set 1 | oussouye
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | atasu
# Processing Record 20 of Set 1 | fortuna
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | saint-georges
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | nouadhibou
# Processing Record 25 of Set 1 | khandyga
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | asau
# Processing Record 28 of Set 1 | rakhya
# City not found. Skipping...
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | kununurra
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | caravelas
# Processing Record 37 of Set 1 | constitucion
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | kaltasy
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | eureka
# Processing Record 44 of Set 1 | santa fe
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | buala
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | bodmin
# Processing Record 1 of Set 2 | bengkulu
# Processing Record 2 of Set 2 | kampot
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | atambua
# Processing Record 5 of Set 2 | flinders
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | olafsvik
# Processing Record 8 of Set 2 | balkhash
# Processing Record 9 of Set 2 | pevek
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | camana
# Processing Record 15 of Set 2 | sampit
# Processing Record 16 of Set 2 | buenos aires
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | benguela
# Processing Record 20 of Set 2 | necochea
# Processing Record 21 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 2 | faanui
# Processing Record 23 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | nyurba
# Processing Record 26 of Set 2 | shizunai
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | morant bay
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | chokurdakh
# Processing Record 31 of Set 2 | kruisfontein
# Processing Record 32 of Set 2 | coquimbo
# Processing Record 33 of Set 2 | mehamn
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | victoria
# Processing Record 37 of Set 2 | narsaq
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | yulara
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | walvis bay
# Processing Record 42 of Set 2 | iqaluit
# Processing Record 43 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | megion
# Processing Record 46 of Set 2 | nemuro
# Processing Record 47 of Set 2 | kirakira
# Processing Record 48 of Set 2 | jawhar
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | dingle
# Processing Record 1 of Set 3 | la ronge
# Processing Record 2 of Set 3 | khatanga
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | mamallapuram
# Processing Record 5 of Set 3 | mercedes
# Processing Record 6 of Set 3 | kaitangata
# Processing Record 7 of Set 3 | leningradskiy
# Processing Record 8 of Set 3 | bosanska krupa
# Processing Record 9 of Set 3 | zhigansk
# Processing Record 10 of Set 3 | sola
# Processing Record 11 of Set 3 | ust-kuyga
# Processing Record 12 of Set 3 | cap malheureux
# Processing Record 13 of Set 3 | ngunguru
# Processing Record 14 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 3 | phalodi
# Processing Record 17 of Set 3 | lucapa
# Processing Record 18 of Set 3 | luanda
# Processing Record 19 of Set 3 | esperance
# Processing Record 20 of Set 3 | ginda
# Processing Record 21 of Set 3 | hobart
# Processing Record 22 of Set 3 | borken
# Processing Record 23 of Set 3 | mahon
# Processing Record 24 of Set 3 | konstantinovka
# Processing Record 25 of Set 3 | vaini
# Processing Record 26 of Set 3 | aykhal
# Processing Record 27 of Set 3 | tiksi
# Processing Record 28 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 29 of Set 3 | qostanay
# Processing Record 30 of Set 3 | salamanca
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | san quintin
# Processing Record 33 of Set 3 | moranbah
# Processing Record 34 of Set 3 | tiarei
# Processing Record 35 of Set 3 | rassvet
# Processing Record 36 of Set 3 | antofagasta
# Processing Record 37 of Set 3 | havoysund
# Processing Record 38 of Set 3 | mugumu
# Processing Record 39 of Set 3 | akdepe
# Processing Record 40 of Set 3 | umred
# Processing Record 41 of Set 3 | auki
# Processing Record 42 of Set 3 | saint-augustin
# Processing Record 43 of Set 3 | mahebourg
# Processing Record 44 of Set 3 | vardo
# Processing Record 45 of Set 3 | leh
# Processing Record 46 of Set 3 | sao filipe
# Processing Record 47 of Set 3 | sobolevo
# Processing Record 48 of Set 3 | dikson
# Processing Record 49 of Set 3 | ratanpur
# Processing Record 50 of Set 3 | oranjemund
# Processing Record 1 of Set 4 | chuy
# Processing Record 2 of Set 4 | vila velha
# Processing Record 3 of Set 4 | emet
# Processing Record 4 of Set 4 | chagoda
# Processing Record 5 of Set 4 | pedernales
# Processing Record 6 of Set 4 | sisimiut
# Processing Record 7 of Set 4 | pangai
# Processing Record 8 of Set 4 | pangnirtung
# Processing Record 9 of Set 4 | comodoro rivadavia
# Processing Record 10 of Set 4 | altagracia de orituco
# Processing Record 11 of Set 4 | hilo
# Processing Record 12 of Set 4 | shache
# Processing Record 13 of Set 4 | fort nelson
# Processing Record 14 of Set 4 | yar-sale
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | jeremie
# Processing Record 17 of Set 4 | sitio novo do tocantins
# Processing Record 18 of Set 4 | arraial do cabo
# Processing Record 19 of Set 4 | kuching
# Processing Record 20 of Set 4 | wicklow
# Processing Record 21 of Set 4 | syasstroy
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | buxar
# Processing Record 24 of Set 4 | ulladulla
# Processing Record 25 of Set 4 | zhanakorgan
# Processing Record 26 of Set 4 | manzanillo
# Processing Record 27 of Set 4 | aklavik
# Processing Record 28 of Set 4 | ahipara
# Processing Record 29 of Set 4 | hargeysa
# Processing Record 30 of Set 4 | tura
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | greenville
# Processing Record 33 of Set 4 | atar
# Processing Record 34 of Set 4 | sholapur
# Processing Record 35 of Set 4 | teguise
# Processing Record 36 of Set 4 | nikolskoye
# Processing Record 37 of Set 4 | castro
# Processing Record 38 of Set 4 | north bend
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | sinnamary
# Processing Record 41 of Set 4 | provideniya
# Processing Record 42 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 4 | inuvik
# Processing Record 44 of Set 4 | qasigiannguit
# Processing Record 45 of Set 4 | tasiilaq
# Processing Record 46 of Set 4 | prince rupert
# Processing Record 47 of Set 4 | whitianga
# Processing Record 48 of Set 4 | kahului
# Processing Record 49 of Set 4 | hervey bay
# Processing Record 50 of Set 4 | huilong
# Processing Record 1 of Set 5 | yanam
# Processing Record 2 of Set 5 | half moon bay
# Processing Record 3 of Set 5 | longfeng
# Processing Record 4 of Set 5 | svetlogorsk
# Processing Record 5 of Set 5 | tuatapere
# Processing Record 6 of Set 5 | bluff
# Processing Record 7 of Set 5 | gravdal
# Processing Record 8 of Set 5 | port blair
# Processing Record 9 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 10 of Set 5 | gawler
# Processing Record 11 of Set 5 | yumen
# Processing Record 12 of Set 5 | kamaishi
# Processing Record 13 of Set 5 | basoko
# Processing Record 14 of Set 5 | bandarbeyla
# Processing Record 15 of Set 5 | hirado
# Processing Record 16 of Set 5 | lorengau
# Processing Record 17 of Set 5 | norman wells
# Processing Record 18 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 5 | sulangan
# Processing Record 20 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 21 of Set 5 | ryotsu
# Processing Record 22 of Set 5 | borazjan
# Processing Record 23 of Set 5 | zvishavane
# Processing Record 24 of Set 5 | monrovia
# Processing Record 25 of Set 5 | agadez
# Processing Record 26 of Set 5 | windhoek
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | saint-francois
# Processing Record 29 of Set 5 | paamiut
# Processing Record 30 of Set 5 | rincon
# Processing Record 31 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 5 | katherine
# Processing Record 33 of Set 5 | sao joao da barra
# Processing Record 34 of Set 5 | surgut
# Processing Record 35 of Set 5 | madang
# Processing Record 36 of Set 5 | griffith
# Processing Record 37 of Set 5 | saint george
# Processing Record 38 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 39 of Set 5 | santiago del estero
# Processing Record 40 of Set 5 | loubomo
# Processing Record 41 of Set 5 | yerofey pavlovich
# Processing Record 42 of Set 5 | berlevag
# Processing Record 43 of Set 5 | isangel
# Processing Record 44 of Set 5 | pietermaritzburg
# Processing Record 45 of Set 5 | bonthe
# Processing Record 46 of Set 5 | grand-lahou
# Processing Record 47 of Set 5 | lagoa
# Processing Record 48 of Set 5 | lalomanu
# City not found. Skipping...
# Processing Record 49 of Set 5 | jiuquan
# Processing Record 50 of Set 5 | kavieng
# Processing Record 1 of Set 6 | oyama
# Processing Record 2 of Set 6 | ixtapa
# Processing Record 3 of Set 6 | lasa
# Processing Record 4 of Set 6 | nerchinskiy zavod
# Processing Record 5 of Set 6 | bambous virieux
# Processing Record 6 of Set 6 | pemba
# Processing Record 7 of Set 6 | teknaf
# Processing Record 8 of Set 6 | obama
# Processing Record 9 of Set 6 | broken hill
# Processing Record 10 of Set 6 | pinega
# Processing Record 11 of Set 6 | concarneau
# Processing Record 12 of Set 6 | inhambane
# Processing Record 13 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 6 | guilin
# Processing Record 15 of Set 6 | roma
# Processing Record 16 of Set 6 | puerto ayacucho
# Processing Record 17 of Set 6 | maku
# Processing Record 18 of Set 6 | lake charles
# Processing Record 19 of Set 6 | tucupita
# Processing Record 20 of Set 6 | la esperanza
# Processing Record 21 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 6 | vreed en hoop
# City not found. Skipping...
# Processing Record 23 of Set 6 | severo-kurilsk
# Processing Record 24 of Set 6 | san pedro de cajas
# Processing Record 25 of Set 6 | itacoatiara
# Processing Record 26 of Set 6 | nosy varika
# Processing Record 27 of Set 6 | nyrob
# Processing Record 28 of Set 6 | general pico
# Processing Record 29 of Set 6 | ambilobe
# Processing Record 30 of Set 6 | nome
# Processing Record 31 of Set 6 | panagar
# Processing Record 32 of Set 6 | chilliwack
# Processing Record 33 of Set 6 | kendari
# Processing Record 34 of Set 6 | dunedin
# Processing Record 35 of Set 6 | jati
# Processing Record 36 of Set 6 | mocuba
# Processing Record 37 of Set 6 | burnie
# Processing Record 38 of Set 6 | mandalgovi
# Processing Record 39 of Set 6 | envira
# Processing Record 40 of Set 6 | cayenne
# Processing Record 41 of Set 6 | borogontsy
# Processing Record 42 of Set 6 | luderitz
# Processing Record 43 of Set 6 | gat
# Processing Record 44 of Set 6 | kiunga
# Processing Record 45 of Set 6 | laguna
# Processing Record 46 of Set 6 | the valley
# Processing Record 47 of Set 6 | biskamzha
# Processing Record 48 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 6 | high level
# Processing Record 50 of Set 6 | dimitrovgrad
# Processing Record 1 of Set 7 | sangar
# Processing Record 2 of Set 7 | salalah
# Processing Record 3 of Set 7 | van
# Processing Record 4 of Set 7 | fare
# Processing Record 5 of Set 7 | chepareria
# Processing Record 6 of Set 7 | seminole
# Processing Record 7 of Set 7 | sabla
# Processing Record 8 of Set 7 | garm
# City not found. Skipping...
# Processing Record 9 of Set 7 | souillac
# Processing Record 10 of Set 7 | ust-tsilma
# Processing Record 11 of Set 7 | tromso
# Processing Record 12 of Set 7 | scarborough
# Processing Record 13 of Set 7 | coolum beach
# Processing Record 14 of Set 7 | upernavik
# Processing Record 15 of Set 7 | lubao
# Processing Record 16 of Set 7 | grand gaube
# Processing Record 17 of Set 7 | puerto penasco
# Processing Record 18 of Set 7 | irtyshskiy
# Processing Record 19 of Set 7 | touros
# Processing Record 20 of Set 7 | kieta
# Processing Record 21 of Set 7 | katsuura
# Processing Record 22 of Set 7 | cherskiy
# Processing Record 23 of Set 7 | tommot
# Processing Record 24 of Set 7 | nanortalik
# Processing Record 25 of Set 7 | salinas
# Processing Record 26 of Set 7 | roald
# Processing Record 27 of Set 7 | svetlaya
# Processing Record 28 of Set 7 | hasaki
# Processing Record 29 of Set 7 | banda aceh
# Processing Record 30 of Set 7 | ust-ishim
# Processing Record 31 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 7 | cumberland
# Processing Record 33 of Set 7 | belmonte
# Processing Record 34 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 7 | mandurah
# Processing Record 36 of Set 7 | astoria
# Processing Record 37 of Set 7 | nacunday
# City not found. Skipping...
# Processing Record 38 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 7 | boa vista
# Processing Record 40 of Set 7 | axim
# Processing Record 41 of Set 7 | mar del plata
# Processing Record 42 of Set 7 | marsaxlokk
# Processing Record 43 of Set 7 | mount gambier
# Processing Record 44 of Set 7 | zastron
# Processing Record 45 of Set 7 | carbonia
# Processing Record 46 of Set 7 | iskateley
# Processing Record 47 of Set 7 | alofi
# Processing Record 48 of Set 7 | amazar
# Processing Record 49 of Set 7 | villa bruzual
# Processing Record 50 of Set 7 | taveta
# Processing Record 1 of Set 8 | bathsheba
# Processing Record 2 of Set 8 | rio gallegos
# Processing Record 3 of Set 8 | santa isabel do rio negro
# Processing Record 4 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 8 | dudinka
# Processing Record 6 of Set 8 | iskandar
# Processing Record 7 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 8 of Set 8 | atka
# City not found. Skipping...
# Processing Record 9 of Set 8 | erzin
# Processing Record 10 of Set 8 | codrington
# Processing Record 11 of Set 8 | nishihara
# Processing Record 12 of Set 8 | lahij
# Processing Record 13 of Set 8 | buchanan
# Processing Record 14 of Set 8 | palmas
# Processing Record 15 of Set 8 | port hardy
# Processing Record 16 of Set 8 | sao geraldo do araguaia
# Processing Record 17 of Set 8 | vestmannaeyjar
# Processing Record 18 of Set 8 | menongue
# Processing Record 19 of Set 8 | omboue
# Processing Record 20 of Set 8 | hofn
# Processing Record 21 of Set 8 | clyde river
# Processing Record 22 of Set 8 | figeac
# Processing Record 23 of Set 8 | hamilton
# Processing Record 24 of Set 8 | coihaique
# Processing Record 25 of Set 8 | puerto carreno
# Processing Record 26 of Set 8 | kayerkan
# Processing Record 27 of Set 8 | avera
# Processing Record 28 of Set 8 | torbay
# Processing Record 29 of Set 8 | madimba
# Processing Record 30 of Set 8 | college
# Processing Record 31 of Set 8 | baruun-urt
# Processing Record 32 of Set 8 | grindavik
# Processing Record 33 of Set 8 | sungaipenuh
# Processing Record 34 of Set 8 | salamiyah
# Processing Record 35 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 8 | talnakh
# Processing Record 37 of Set 8 | tigil
# Processing Record 38 of Set 8 | bubaque
# Processing Record 39 of Set 8 | batticaloa
# Processing Record 40 of Set 8 | waingapu
# Processing Record 41 of Set 8 | tezu
# Processing Record 42 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 8 | mitu
# Processing Record 44 of Set 8 | itarema
# Processing Record 45 of Set 8 | northam
# Processing Record 46 of Set 8 | murgab
# Processing Record 47 of Set 8 | baykit
# Processing Record 48 of Set 8 | prainha
# Processing Record 49 of Set 8 | port macquarie
# Processing Record 50 of Set 8 | oksfjord
# Processing Record 1 of Set 9 | vurnary
# Processing Record 2 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 9 | meulaboh
# Processing Record 4 of Set 9 | saskylakh
# Processing Record 5 of Set 9 | nanning
# Processing Record 6 of Set 9 | bethal
# Processing Record 7 of Set 9 | azle
# Processing Record 8 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 9 | puerto escondido
# Processing Record 10 of Set 9 | acapulco
# Processing Record 11 of Set 9 | xingyi
# Processing Record 12 of Set 9 | teahupoo
# Processing Record 13 of Set 9 | zlitan
# Processing Record 14 of Set 9 | kpalime
# Processing Record 15 of Set 9 | kedrovyy
# Processing Record 16 of Set 9 | barcelos
# Processing Record 17 of Set 9 | conceicao do araguaia
# Processing Record 18 of Set 9 | lagos
# Processing Record 19 of Set 9 | russell
# Processing Record 20 of Set 9 | george town
# Processing Record 21 of Set 9 | tecoanapa
# Processing Record 22 of Set 9 | malazgirt
# Processing Record 23 of Set 9 | kutum
# Processing Record 24 of Set 9 | terrace bay
# Processing Record 25 of Set 9 | los llanos de aridane
# Processing Record 26 of Set 9 | sillod
# Processing Record 27 of Set 9 | kandi
# Processing Record 28 of Set 9 | wasilla
# Processing Record 29 of Set 9 | porto belo
# Processing Record 30 of Set 9 | padang
# Processing Record 31 of Set 9 | guerrero negro
# Processing Record 32 of Set 9 | thinadhoo
# Processing Record 33 of Set 9 | atikokan
# Processing Record 34 of Set 9 | charters towers
# Processing Record 35 of Set 9 | saldanha
# Processing Record 36 of Set 9 | hay river
# Processing Record 37 of Set 9 | qandala
# Processing Record 38 of Set 9 | hwange
# Processing Record 39 of Set 9 | bitburg
# Processing Record 40 of Set 9 | dormagen
# Processing Record 41 of Set 9 | rodez
# Processing Record 42 of Set 9 | owo
# Processing Record 43 of Set 9 | chernyshevsk
# Processing Record 44 of Set 9 | hoa binh
# Processing Record 45 of Set 9 | vung tau
# Processing Record 46 of Set 9 | swellendam
# Processing Record 47 of Set 9 | vostok
# Processing Record 48 of Set 9 | chuguyevka
# Processing Record 49 of Set 9 | gagra
# Processing Record 50 of Set 9 | kaeo
# Processing Record 1 of Set 10 | broome
# Processing Record 2 of Set 10 | pauini
# Processing Record 3 of Set 10 | kismayo
# Processing Record 4 of Set 10 | namibe
# Processing Record 5 of Set 10 | umm lajj
# Processing Record 6 of Set 10 | dawei
# Processing Record 7 of Set 10 | hami
# Processing Record 8 of Set 10 | male
# Processing Record 9 of Set 10 | vryburg
# Processing Record 10 of Set 10 | joshimath
# Processing Record 11 of Set 10 | davila
# Processing Record 12 of Set 10 | kyshtovka
# Processing Record 13 of Set 10 | ahuimanu
# Processing Record 14 of Set 10 | xining
# Processing Record 15 of Set 10 | penzance
# Processing Record 16 of Set 10 | bavly
# Processing Record 17 of Set 10 | seydi
# Processing Record 18 of Set 10 | hobyo
# Processing Record 19 of Set 10 | kattivakkam
# Processing Record 20 of Set 10 | dapaong
# Processing Record 21 of Set 10 | haines junction
# Processing Record 22 of Set 10 | mae sai
# Processing Record 23 of Set 10 | kloulklubed
# Processing Record 24 of Set 10 | manakara
# Processing Record 25 of Set 10 | pindiga
# Processing Record 26 of Set 10 | sicuani
# Processing Record 27 of Set 10 | san andres
# Processing Record 28 of Set 10 | namatanai
# Processing Record 29 of Set 10 | fuerte olimpo
# Processing Record 30 of Set 10 | vao
# Processing Record 31 of Set 10 | sao miguel do araguaia
# Processing Record 32 of Set 10 | cabo san lucas
# Processing Record 33 of Set 10 | svetlyy
# Processing Record 34 of Set 10 | alta floresta
# Processing Record 35 of Set 10 | uvat
# Processing Record 36 of Set 10 | unye
# City not found. Skipping...
# Processing Record 37 of Set 10 | obo
# Processing Record 38 of Set 10 | waipawa
# Processing Record 39 of Set 10 | goderich
# Processing Record 40 of Set 10 | hammerfest
# Processing Record 41 of Set 10 | maroantsetra
# Processing Record 42 of Set 10 | ostrovnoy
# Processing Record 43 of Set 10 | lewiston
# Processing Record 44 of Set 10 | santa cruz del sur
# Processing Record 45 of Set 10 | yarmouth
# Processing Record 46 of Set 10 | ye
# City not found. Skipping...
# Processing Record 47 of Set 10 | sao joao dos patos
# Processing Record 48 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 10 | san patricio
# Processing Record 50 of Set 10 | beruni
# City not found. Skipping...
# Processing Record 1 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 2 of Set 11 | juneau
# Processing Record 3 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 11 | lar gerd
# City not found. Skipping...
# Processing Record 5 of Set 11 | amargosa
# Processing Record 6 of Set 11 | nuevo progreso
# Processing Record 7 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 11 | pombas
# Processing Record 9 of Set 11 | yantal
# Processing Record 10 of Set 11 | bolgatanga
# Processing Record 11 of Set 11 | raduzhnyy
# Processing Record 12 of Set 11 | carballo
# Processing Record 13 of Set 11 | jizan
# Processing Record 14 of Set 11 | kindia
# Processing Record 15 of Set 11 | burns lake
# Processing Record 16 of Set 11 | aktau
# Processing Record 17 of Set 11 | ayagoz
# Processing Record 18 of Set 11 | mbandaka
# Processing Record 19 of Set 11 | kushmurun
# Processing Record 20 of Set 11 | sibu
# Processing Record 21 of Set 11 | old saybrook
# Processing Record 22 of Set 11 | vila franca do campo
# Processing Record 23 of Set 11 | alcaniz
# Processing Record 24 of Set 11 | miandrivazo
# Processing Record 25 of Set 11 | port hawkesbury
# Processing Record 26 of Set 11 | rocha
# Processing Record 27 of Set 11 | ulaangom
# Processing Record 28 of Set 11 | matamba
# Processing Record 29 of Set 11 | chapais
# Processing Record 30 of Set 11 | fairbanks
# Processing Record 31 of Set 11 | erdaojiang
# Processing Record 32 of Set 11 | talaya
# Processing Record 33 of Set 11 | arroio grande
# Processing Record 34 of Set 11 | jibuti
# Processing Record 35 of Set 11 | faya
# Processing Record 36 of Set 11 | acajutla
# Processing Record 37 of Set 11 | saint-pierre
# Processing Record 38 of Set 11 | alizai
# Processing Record 39 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 40 of Set 11 | austin
# Processing Record 41 of Set 11 | hovd
# Processing Record 42 of Set 11 | mao
# Processing Record 43 of Set 11 | alexandria
# Processing Record 44 of Set 11 | cesky krumlov
# Processing Record 45 of Set 11 | chabahar
# Processing Record 46 of Set 11 | hun
# Processing Record 47 of Set 11 | adrar
# Processing Record 48 of Set 11 | moa
# Processing Record 49 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 50 of Set 11 | vysokogornyy
# Processing Record 1 of Set 12 | laval
# Processing Record 2 of Set 12 | porto torres
# Processing Record 3 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 12 | tiznit
# Processing Record 5 of Set 12 | nouakchott
# Processing Record 6 of Set 12 | tabuk
# Processing Record 7 of Set 12 | bamut
# Processing Record 8 of Set 12 | nelson bay
# Processing Record 9 of Set 12 | ondangwa
# Processing Record 10 of Set 12 | hambantota
# Processing Record 11 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 12 | arenapolis
# Processing Record 13 of Set 12 | shingu
# Processing Record 14 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 12 | mahibadhoo
# Processing Record 16 of Set 12 | aksu
# Processing Record 17 of Set 12 | aquiraz
# Processing Record 18 of Set 12 | jaypur
# Processing Record 19 of Set 12 | peleduy
# Processing Record 20 of Set 12 | kathor
# Processing Record 21 of Set 12 | cockburn town
# Processing Record 22 of Set 12 | witu
# Processing Record 23 of Set 12 | paso de carrasco
# Processing Record 24 of Set 12 | tucuman
# Processing Record 25 of Set 12 | kingston
# Processing Record 26 of Set 12 | epe
# Processing Record 27 of Set 12 | balgazyn
# Processing Record 28 of Set 12 | pathein
# Processing Record 29 of Set 12 | biak
# Processing Record 30 of Set 12 | flin flon
# Processing Record 31 of Set 12 | lata
# Processing Record 32 of Set 12 | bambanglipuro
# Processing Record 33 of Set 12 | san cristobal
# Processing Record 34 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 12 | bilibino
# Processing Record 36 of Set 12 | chino valley
# Processing Record 37 of Set 12 | totma
# Processing Record 38 of Set 12 | yian
# City not found. Skipping...
# Processing Record 39 of Set 12 | boddam
# Processing Record 40 of Set 12 | cooma
# Processing Record 41 of Set 12 | batagay-alyta
# Processing Record 42 of Set 12 | tessalit
# Processing Record 43 of Set 12 | mokolo
# Processing Record 44 of Set 12 | maragogi
# Processing Record 45 of Set 12 | taoudenni
# Processing Record 46 of Set 12 | akureyri
# Processing Record 47 of Set 12 | toamasina
# Processing Record 48 of Set 12 | itacare
# Processing Record 49 of Set 12 | wad madani
# Processing Record 50 of Set 12 | suraabad
# Processing Record 1 of Set 13 | dakar
# Processing Record 2 of Set 13 | inta
# Processing Record 3 of Set 13 | high rock
# Processing Record 4 of Set 13 | khabary
# Processing Record 5 of Set 13 | vila
# Processing Record 6 of Set 13 | shakhovskaya
# Processing Record 7 of Set 13 | burica
# City not found. Skipping...
# Processing Record 8 of Set 13 | carmen
# Processing Record 9 of Set 13 | port-gentil
# Processing Record 10 of Set 13 | jhusi
# Processing Record 11 of Set 13 | luzhou
# Processing Record 12 of Set 13 | pisco
# Processing Record 13 of Set 13 | lauingen
# Processing Record 14 of Set 13 | poum
# Processing Record 15 of Set 13 | ladario
# Processing Record 16 of Set 13 | zeya
# Processing Record 17 of Set 13 | kuytun
# Processing Record 18 of Set 13 | honolulu
# Processing Record 19 of Set 13 | bang saphan
# Processing Record 20 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 13 | mormugao
# Processing Record 22 of Set 13 | kemijarvi
# Processing Record 23 of Set 13 | sorland
# Processing Record 24 of Set 13 | peterhead
# Processing Record 25 of Set 13 | shimoda
# Processing Record 26 of Set 13 | vanavara
# Processing Record 27 of Set 13 | muros
# Processing Record 28 of Set 13 | nantucket
# Processing Record 29 of Set 13 | ust-maya
# Processing Record 30 of Set 13 | plettenberg bay
# Processing Record 31 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 32 of Set 13 | brae
# Processing Record 33 of Set 13 | trairi
# Processing Record 34 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 35 of Set 13 | alyangula
# Processing Record 36 of Set 13 | kupino
# Processing Record 37 of Set 13 | black river
# Processing Record 38 of Set 13 | normandin
# Processing Record 39 of Set 13 | alugan
# Processing Record 40 of Set 13 | anchorage
# Processing Record 41 of Set 13 | iralaya
# Processing Record 42 of Set 13 | blagoyevo
# Processing Record 43 of Set 13 | fruitvale
# Processing Record 44 of Set 13 | chicama
# Processing Record 45 of Set 13 | parrita
# Processing Record 46 of Set 13 | omsukchan
# Processing Record 47 of Set 13 | arona
# Processing Record 48 of Set 13 | gagnoa
# Processing Record 49 of Set 13 | altamont
# Processing Record 50 of Set 13 | kudahuvadhoo
# Processing Record 1 of Set 14 | orotukan
# Processing Record 2 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 3 of Set 14 | tunxi
# City not found. Skipping...
# Processing Record 4 of Set 14 | rafai
# Processing Record 5 of Set 14 | denpasar
# Processing Record 6 of Set 14 | nuuk
# Processing Record 7 of Set 14 | gornyatskiy
# Processing Record 8 of Set 14 | mattru
# Processing Record 9 of Set 14 | jabinyanah
# Processing Record 10 of Set 14 | helong
# Processing Record 11 of Set 14 | salinopolis
# Processing Record 12 of Set 14 | qobustan
# Processing Record 13 of Set 14 | ishigaki
# Processing Record 14 of Set 14 | kenai
# Processing Record 15 of Set 14 | lagunillas
# Processing Record 16 of Set 14 | nalut
# Processing Record 17 of Set 14 | nata
# Processing Record 18 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 19 of Set 14 | montpelier
# Processing Record 20 of Set 14 | kropotkin
# Processing Record 21 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 14 | christchurch
# Processing Record 23 of Set 14 | tanout
# Processing Record 24 of Set 14 | merauke
# Processing Record 25 of Set 14 | naze
# Processing Record 26 of Set 14 | cape elizabeth
# City not found. Skipping...
# Processing Record 27 of Set 14 | venado tuerto
# Processing Record 28 of Set 14 | dawlatabad
# Processing Record 29 of Set 14 | novyy urengoy
# Processing Record 30 of Set 14 | huarmey
# Processing Record 31 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 14 | portel
# Processing Record 33 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 14 | houma
# Processing Record 35 of Set 14 | mahajanga
# Processing Record 36 of Set 14 | husavik
# Processing Record 37 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 14 | berezovyy
# Processing Record 39 of Set 14 | bahia blanca
# Processing Record 40 of Set 14 | sur
# Processing Record 41 of Set 14 | nhamunda
# Processing Record 42 of Set 14 | kuala perlis
# Processing Record 43 of Set 14 | abu samrah
# Processing Record 44 of Set 14 | newton
# Processing Record 45 of Set 14 | kamenka
# Processing Record 46 of Set 14 | semnan
# Processing Record 47 of Set 14 | kawalu
# Processing Record 48 of Set 14 | kushima
# Processing Record 49 of Set 14 | bimbo
# Processing Record 50 of Set 14 | marzuq
# Processing Record 1 of Set 15 | shahr-e babak
# Processing Record 2 of Set 15 | peniche
# Processing Record 3 of Set 15 | tubmanburg
# Processing Record 4 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 15 | honningsvag
# Processing Record 6 of Set 15 | ereymentau
# Processing Record 7 of Set 15 | harper
# Processing Record 8 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 9 of Set 15 | shenjiamen
# Processing Record 10 of Set 15 | saint-michel-des-saints
# Processing Record 11 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 12 of Set 15 | jiaojiang
# Processing Record 13 of Set 15 | lavrentiya
# Processing Record 14 of Set 15 | tombouctou
# Processing Record 15 of Set 15 | pandan
# Processing Record 16 of Set 15 | koshurnikovo
# Processing Record 17 of Set 15 | michigan city
# Processing Record 18 of Set 15 | ust-nera
# Processing Record 19 of Set 15 | jiaonan
# Processing Record 20 of Set 15 | bercel
# Processing Record 21 of Set 15 | anadyr
# Processing Record 22 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 23 of Set 15 | lindeberg
# Processing Record 24 of Set 15 | petaluma
# Processing Record 25 of Set 15 | gornozavodsk
# Processing Record 26 of Set 15 | gorele
# Processing Record 27 of Set 15 | windsor
# Processing Record 28 of Set 15 | trinidad
# Processing Record 29 of Set 15 | cetate
# Processing Record 30 of Set 15 | hualmay
# Processing Record 31 of Set 15 | westport
# Processing Record 32 of Set 15 | amga
# Processing Record 33 of Set 15 | great bend
# Processing Record 34 of Set 15 | stornoway
# Processing Record 35 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 15 | nizwa
# Processing Record 37 of Set 15 | villaviciosa
# Processing Record 38 of Set 15 | bagotville
# Processing Record 39 of Set 15 | kalispell
# Processing Record 40 of Set 15 | hit
# Processing Record 41 of Set 15 | namie
# Processing Record 42 of Set 15 | shelburne
# Processing Record 43 of Set 15 | portachuelo
# Processing Record 44 of Set 15 | carupano
# Processing Record 45 of Set 15 | copiapo
# Processing Record 46 of Set 15 | creel
# Processing Record 47 of Set 15 | timmins
# Processing Record 48 of Set 15 | savino
# Processing Record 49 of Set 15 | ocampo
# Processing Record 50 of Set 15 | corn island
# Processing Record 1 of Set 16 | itoman
# Processing Record 2 of Set 16 | johnstown
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rawson -43.3002  -65.1023     54.21        74           9
# 1       Thompson  55.7435  -97.8558     14.16        92          90
# 2   Komsomolskiy  40.4272   71.7189     42.22        52           2
# 3  West Wendover  40.7391 -114.0733     34.81        44          90
# 4          Zemio   5.0314   25.1361     81.46        62          87
# 5        Mataura -46.1927  168.8643     57.31        54          95
# 6   Beringovskiy  63.0500  179.3167     22.39        74         100
# 7     Skibbereen  51.5500   -9.2667     48.00        87          93
# 8       Hermanus -34.4187   19.2345     69.91        52          75
# 9      Vincennes  48.8500    2.4333     48.00        94          90
#
#    Wind Speed Country Current Description
# 0       19.17      AR           clear sky
# 1        5.75      CA     overcast clouds
# 2        4.61      UZ                haze
# 3        0.00      US     overcast clouds
# 4        3.83      CF     overcast clouds
# 5        7.31      NZ     overcast clouds
# 6       15.90      RU     overcast clouds
# 7        8.48      IE     overcast clouds
# 8        7.83      ZA       broken clouds
# 9        4.61      FR     overcast clouds

# %%
column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# %%
city_data_df=city_data_df[column_order]

city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rawson      AR -43.3002  -65.1023     54.21        74           9
# 1       Thompson      CA  55.7435  -97.8558     14.16        92          90
# 2   Komsomolskiy      UZ  40.4272   71.7189     42.22        52           2
# 3  West Wendover      US  40.7391 -114.0733     34.81        44          90
# 4          Zemio      CF   5.0314   25.1361     81.46        62          87
# 5        Mataura      NZ -46.1927  168.8643     57.31        54          95
# 6   Beringovskiy      RU  63.0500  179.3167     22.39        74         100
# 7     Skibbereen      IE  51.5500   -9.2667     48.00        87          93
# 8       Hermanus      ZA -34.4187   19.2345     69.91        52          75
# 9      Vincennes      FR  48.8500    2.4333     48.00        94          90
#
#    Wind Speed Current Description
# 0       19.17           clear sky
# 1        5.75     overcast clouds
# 2        4.61                haze
# 3        0.00     overcast clouds
# 4        3.83     overcast clouds
# 5        7.31     overcast clouds
# 6       15.90     overcast clouds
# 7        8.48     overcast clouds
# 8        7.83       broken clouds
# 9        4.61     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
