# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
import requests

# Import the API key.
from config import weather_api_key

import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cozumel
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | poum
# Processing Record 9 of Set 1 | kinsale
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | araripe
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | addis zemen
# City not found. Skipping...
# Processing Record 15 of Set 1 | saint george
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | abha
# Processing Record 19 of Set 1 | fort nelson
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | beira
# Processing Record 25 of Set 1 | lorengau
# Processing Record 26 of Set 1 | manono
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | nanortalik
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | yongan
# Processing Record 32 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 1 | zamania
# Processing Record 34 of Set 1 | inhambane
# Processing Record 35 of Set 1 | ipixuna
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | oranjemund
# Processing Record 38 of Set 1 | at-bashi
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | salinopolis
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | nemuro
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | taoudenni
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | sedelnikovo
# City not found. Skipping...
# Processing Record 50 of Set 1 | totma
# Processing Record 1 of Set 2 | uglovskoye
# Processing Record 2 of Set 2 | pindiga
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | saint anthony
# Processing Record 5 of Set 2 | bandarbeyla
# Processing Record 6 of Set 2 | buta
# Processing Record 7 of Set 2 | susangerd
# Processing Record 8 of Set 2 | tahe
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | maneadero
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | yele
# Processing Record 15 of Set 2 | marsh harbour
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | makakilo city
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | cockburn town
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | barguzin
# Processing Record 22 of Set 2 | ancud
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | haines junction
# Processing Record 25 of Set 2 | marsaxlokk
# Processing Record 26 of Set 2 | esperance
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | saint-pierre
# Processing Record 31 of Set 2 | porto walter
# Processing Record 32 of Set 2 | saint-augustin
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | puerto escondido
# Processing Record 35 of Set 2 | manzil tamim
# City not found. Skipping...
# Processing Record 36 of Set 2 | ixtapa
# Processing Record 37 of Set 2 | surgut
# Processing Record 38 of Set 2 | dingle
# Processing Record 39 of Set 2 | basco
# Processing Record 40 of Set 2 | lidkoping
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | qasigiannguit
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | marzuq
# Processing Record 45 of Set 2 | bonthe
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | chinhoyi
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | northam
# Processing Record 50 of Set 2 | ushuaia
# Processing Record 1 of Set 3 | mumford
# Processing Record 2 of Set 3 | ginir
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | chokurdakh
# Processing Record 5 of Set 3 | lagoa
# Processing Record 6 of Set 3 | hasaki
# Processing Record 7 of Set 3 | east london
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 3 | souillac
# Processing Record 13 of Set 3 | katherine
# Processing Record 14 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 3 | olinda
# Processing Record 17 of Set 3 | waipawa
# Processing Record 18 of Set 3 | tiksi
# Processing Record 19 of Set 3 | mayo
# Processing Record 20 of Set 3 | katha
# City not found. Skipping...
# Processing Record 21 of Set 3 | moyobamba
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | liverpool
# Processing Record 24 of Set 3 | nhulunbuy
# Processing Record 25 of Set 3 | maniitsoq
# Processing Record 26 of Set 3 | bluff
# Processing Record 27 of Set 3 | oliveira dos brejinhos
# Processing Record 28 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 3 | nikolskoye
# Processing Record 30 of Set 3 | burica
# City not found. Skipping...
# Processing Record 31 of Set 3 | lahan
# Processing Record 32 of Set 3 | sokolo
# Processing Record 33 of Set 3 | ubata
# Processing Record 34 of Set 3 | muzhi
# Processing Record 35 of Set 3 | ostersund
# Processing Record 36 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 37 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 38 of Set 3 | hami
# Processing Record 39 of Set 3 | georgetown
# Processing Record 40 of Set 3 | nanchang
# Processing Record 41 of Set 3 | pochutla
# Processing Record 42 of Set 3 | kupang
# Processing Record 43 of Set 3 | oktyabrskoye
# Processing Record 44 of Set 3 | victoria
# Processing Record 45 of Set 3 | umm lajj
# Processing Record 46 of Set 3 | manuk mangkaw
# Processing Record 47 of Set 3 | narsaq
# Processing Record 48 of Set 3 | bambous virieux
# Processing Record 49 of Set 3 | vila franca do campo
# Processing Record 50 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 4 | neka
# Processing Record 2 of Set 4 | clyde river
# Processing Record 3 of Set 4 | gornopravdinsk
# Processing Record 4 of Set 4 | gillette
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | aklavik
# Processing Record 7 of Set 4 | kaeo
# Processing Record 8 of Set 4 | vostok
# Processing Record 9 of Set 4 | port blair
# Processing Record 10 of Set 4 | deputatskiy
# Processing Record 11 of Set 4 | provideniya
# Processing Record 12 of Set 4 | wadi maliz
# Processing Record 13 of Set 4 | maymyo
# Processing Record 14 of Set 4 | rawson
# Processing Record 15 of Set 4 | avera
# Processing Record 16 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 4 | north bend
# Processing Record 18 of Set 4 | iqaluit
# Processing Record 19 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 4 | elko
# Processing Record 21 of Set 4 | sovetsk
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 24 of Set 4 | berlevag
# Processing Record 25 of Set 4 | riyadh
# Processing Record 26 of Set 4 | blonduos
# City not found. Skipping...
# Processing Record 27 of Set 4 | broome
# Processing Record 28 of Set 4 | nome
# Processing Record 29 of Set 4 | aswan
# Processing Record 30 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 4 | anloga
# Processing Record 33 of Set 4 | ankazoabo
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | pacifica
# Processing Record 36 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 4 | te anau
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | taltal
# Processing Record 40 of Set 4 | bilibino
# Processing Record 41 of Set 4 | atar
# Processing Record 42 of Set 4 | chuy
# Processing Record 43 of Set 4 | chicama
# Processing Record 44 of Set 4 | okulovka
# Processing Record 45 of Set 4 | thinadhoo
# Processing Record 46 of Set 4 | san jose
# Processing Record 47 of Set 4 | ballina
# Processing Record 48 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 4 | vuktyl
# Processing Record 50 of Set 4 | vao
# Processing Record 1 of Set 5 | mehamn
# Processing Record 2 of Set 5 | beloha
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | eydhafushi
# Processing Record 5 of Set 5 | keti bandar
# Processing Record 6 of Set 5 | coihaique
# Processing Record 7 of Set 5 | mount gambier
# Processing Record 8 of Set 5 | birin
# Processing Record 9 of Set 5 | chara
# Processing Record 10 of Set 5 | pudozh
# Processing Record 11 of Set 5 | pierre
# Processing Record 12 of Set 5 | talcahuano
# Processing Record 13 of Set 5 | qandala
# Processing Record 14 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 5 | poltava
# Processing Record 16 of Set 5 | lusaka
# Processing Record 17 of Set 5 | lavrentiya
# Processing Record 18 of Set 5 | mount pleasant
# Processing Record 19 of Set 5 | vardo
# Processing Record 20 of Set 5 | wanparti
# Processing Record 21 of Set 5 | zhangjiakou
# Processing Record 22 of Set 5 | bengkulu
# Processing Record 23 of Set 5 | manta
# Processing Record 24 of Set 5 | tokonou
# Processing Record 25 of Set 5 | dukat
# Processing Record 26 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 5 | tiznit
# Processing Record 28 of Set 5 | caravelas
# Processing Record 29 of Set 5 | isangel
# Processing Record 30 of Set 5 | asosa
# Processing Record 31 of Set 5 | kalengwa
# Processing Record 32 of Set 5 | yanam
# Processing Record 33 of Set 5 | veliko gradiste
# Processing Record 34 of Set 5 | strelka
# Processing Record 35 of Set 5 | hilo
# Processing Record 36 of Set 5 | sarkand
# Processing Record 37 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 5 | cookeville
# Processing Record 39 of Set 5 | grinnell
# Processing Record 40 of Set 5 | bereda
# Processing Record 41 of Set 5 | wajid
# Processing Record 42 of Set 5 | komsomolskiy
# Processing Record 43 of Set 5 | port-gentil
# Processing Record 44 of Set 5 | zhitikara
# City not found. Skipping...
# Processing Record 45 of Set 5 | beringovskiy
# Processing Record 46 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 5 | luderitz
# Processing Record 48 of Set 5 | batagay-alyta
# Processing Record 49 of Set 5 | baunatal
# Processing Record 50 of Set 5 | norwich
# Processing Record 1 of Set 6 | tarabuco
# Processing Record 2 of Set 6 | fort abbas
# Processing Record 3 of Set 6 | saldanha
# Processing Record 4 of Set 6 | barcelona
# Processing Record 5 of Set 6 | miraflores
# Processing Record 6 of Set 6 | veranopolis
# Processing Record 7 of Set 6 | portland
# Processing Record 8 of Set 6 | necochea
# Processing Record 9 of Set 6 | bacolod
# Processing Record 10 of Set 6 | flin flon
# Processing Record 11 of Set 6 | faanui
# Processing Record 12 of Set 6 | pevek
# Processing Record 13 of Set 6 | padang
# Processing Record 14 of Set 6 | comodoro rivadavia
# Processing Record 15 of Set 6 | klaksvik
# Processing Record 16 of Set 6 | sosnovo
# Processing Record 17 of Set 6 | bubaque
# Processing Record 18 of Set 6 | kargasok
# Processing Record 19 of Set 6 | daru
# Processing Record 20 of Set 6 | grindavik
# Processing Record 21 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 6 | touros
# Processing Record 23 of Set 6 | podosinovets
# Processing Record 24 of Set 6 | mount isa
# Processing Record 25 of Set 6 | paamiut
# Processing Record 26 of Set 6 | labuhan
# Processing Record 27 of Set 6 | egvekinot
# Processing Record 28 of Set 6 | arcos
# Processing Record 29 of Set 6 | mirnyy
# Processing Record 30 of Set 6 | bima
# Processing Record 31 of Set 6 | ambovombe
# Processing Record 32 of Set 6 | pitimbu
# Processing Record 33 of Set 6 | leshukonskoye
# Processing Record 34 of Set 6 | sept-iles
# Processing Record 35 of Set 6 | selty
# Processing Record 36 of Set 6 | krasnoarmeysk
# Processing Record 37 of Set 6 | xiaoweizhai
# Processing Record 38 of Set 6 | san lazaro
# Processing Record 39 of Set 6 | cap malheureux
# Processing Record 40 of Set 6 | zlobin
# Processing Record 41 of Set 6 | faya
# Processing Record 42 of Set 6 | nautanwa
# Processing Record 43 of Set 6 | bocas del toro
# Processing Record 44 of Set 6 | tura
# Processing Record 45 of Set 6 | meulaboh
# Processing Record 46 of Set 6 | jhang
# Processing Record 47 of Set 6 | gobabis
# Processing Record 48 of Set 6 | sao jose da coroa grande
# Processing Record 49 of Set 6 | tomari
# Processing Record 50 of Set 6 | vila
# Processing Record 1 of Set 7 | rzhev
# Processing Record 2 of Set 7 | namibe
# Processing Record 3 of Set 7 | korla
# Processing Record 4 of Set 7 | birjand
# Processing Record 5 of Set 7 | khasan
# Processing Record 6 of Set 7 | camacha
# Processing Record 7 of Set 7 | kamphaeng phet
# Processing Record 8 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 9 of Set 7 | darab
# Processing Record 10 of Set 7 | dunedin
# Processing Record 11 of Set 7 | arti
# Processing Record 12 of Set 7 | sabang
# Processing Record 13 of Set 7 | jiuquan
# Processing Record 14 of Set 7 | biltine
# Processing Record 15 of Set 7 | rio gallegos
# Processing Record 16 of Set 7 | palu
# Processing Record 17 of Set 7 | kohtla-nomme
# Processing Record 18 of Set 7 | codrington
# Processing Record 19 of Set 7 | lahaina
# Processing Record 20 of Set 7 | puerto leguizamo
# Processing Record 21 of Set 7 | surin
# Processing Record 22 of Set 7 | ahipara
# Processing Record 23 of Set 7 | takoradi
# Processing Record 24 of Set 7 | luziania
# Processing Record 25 of Set 7 | ponta do sol
# Processing Record 26 of Set 7 | machali
# Processing Record 27 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 7 | ilhabela
# Processing Record 29 of Set 7 | jacareacanga
# Processing Record 30 of Set 7 | kavieng
# Processing Record 31 of Set 7 | mantua
# Processing Record 32 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 7 | domoni
# Processing Record 34 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 35 of Set 7 | canutama
# Processing Record 36 of Set 7 | gulbene
# Processing Record 37 of Set 7 | lyubymivka
# Processing Record 38 of Set 7 | bonavista
# Processing Record 39 of Set 7 | belmonte
# Processing Record 40 of Set 7 | katsuura
# Processing Record 41 of Set 7 | vilcun
# Processing Record 42 of Set 7 | kaura namoda
# Processing Record 43 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 7 | alanya
# Processing Record 45 of Set 7 | sitka
# Processing Record 46 of Set 7 | waingapu
# Processing Record 47 of Set 7 | zatreni
# Processing Record 48 of Set 7 | srandakan
# Processing Record 49 of Set 7 | lompoc
# Processing Record 50 of Set 7 | genhe
# Processing Record 1 of Set 8 | carutapera
# Processing Record 2 of Set 8 | edmonton
# Processing Record 3 of Set 8 | monte alegre
# Processing Record 4 of Set 8 | patiya
# Processing Record 5 of Set 8 | kyaikkami
# Processing Record 6 of Set 8 | skjold
# Processing Record 7 of Set 8 | antofagasta
# Processing Record 8 of Set 8 | margate
# Processing Record 9 of Set 8 | north platte
# Processing Record 10 of Set 8 | mahajanga
# Processing Record 11 of Set 8 | darhan
# Processing Record 12 of Set 8 | zaqatala
# Processing Record 13 of Set 8 | luxor
# Processing Record 14 of Set 8 | pangnirtung
# Processing Record 15 of Set 8 | bousse
# Processing Record 16 of Set 8 | viesca
# Processing Record 17 of Set 8 | sorland
# Processing Record 18 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 8 | reporoa
# Processing Record 20 of Set 8 | tillabery
# City not found. Skipping...
# Processing Record 21 of Set 8 | pangkalanbuun
# Processing Record 22 of Set 8 | teguldet
# Processing Record 23 of Set 8 | havre-saint-pierre
# Processing Record 24 of Set 8 | srednekolymsk
# Processing Record 25 of Set 8 | zhezkazgan
# Processing Record 26 of Set 8 | vermilion
# Processing Record 27 of Set 8 | bin qirdan
# Processing Record 28 of Set 8 | bilma
# Processing Record 29 of Set 8 | puro
# Processing Record 30 of Set 8 | ca mau
# Processing Record 31 of Set 8 | constitucion
# Processing Record 32 of Set 8 | los llanos de aridane
# Processing Record 33 of Set 8 | dabakala
# Processing Record 34 of Set 8 | tateyama
# Processing Record 35 of Set 8 | teya
# Processing Record 36 of Set 8 | havelock
# Processing Record 37 of Set 8 | neyshabur
# Processing Record 38 of Set 8 | umea
# Processing Record 39 of Set 8 | vilyuysk
# Processing Record 40 of Set 8 | nishihara
# Processing Record 41 of Set 8 | atikokan
# Processing Record 42 of Set 8 | shache
# Processing Record 43 of Set 8 | shingu
# Processing Record 44 of Set 8 | flinders
# Processing Record 45 of Set 8 | hambantota
# Processing Record 46 of Set 8 | garden city
# Processing Record 47 of Set 8 | jumla
# Processing Record 48 of Set 8 | yumen
# Processing Record 49 of Set 8 | mahibadhoo
# Processing Record 50 of Set 8 | muros
# Processing Record 1 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 2 of Set 9 | ormara
# Processing Record 3 of Set 9 | vestmannaeyjar
# Processing Record 4 of Set 9 | nalut
# Processing Record 5 of Set 9 | lufilufi
# Processing Record 6 of Set 9 | barahan
# Processing Record 7 of Set 9 | kumluca
# Processing Record 8 of Set 9 | tessalit
# Processing Record 9 of Set 9 | coquimbo
# Processing Record 10 of Set 9 | guadalupe y calvo
# Processing Record 11 of Set 9 | sao joao da barra
# Processing Record 12 of Set 9 | nizhniy tsasuchey
# Processing Record 13 of Set 9 | springdale
# Processing Record 14 of Set 9 | naryan-mar
# Processing Record 15 of Set 9 | plouzane
# Processing Record 16 of Set 9 | rio grande
# Processing Record 17 of Set 9 | andenes
# Processing Record 18 of Set 9 | baykit
# Processing Record 19 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 20 of Set 9 | aleksandrov gay
# Processing Record 21 of Set 9 | valparaiso
# Processing Record 22 of Set 9 | namatanai
# Processing Record 23 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 24 of Set 9 | san quintin
# Processing Record 25 of Set 9 | walla walla
# Processing Record 26 of Set 9 | tondano
# Processing Record 27 of Set 9 | quimperle
# Processing Record 28 of Set 9 | maningrida
# Processing Record 29 of Set 9 | karratha
# Processing Record 30 of Set 9 | kieta
# Processing Record 31 of Set 9 | sao filipe
# Processing Record 32 of Set 9 | nabire
# Processing Record 33 of Set 9 | diamantina
# Processing Record 34 of Set 9 | iwaki
# Processing Record 35 of Set 9 | port keats
# Processing Record 36 of Set 9 | new iberia
# Processing Record 37 of Set 9 | dakar
# Processing Record 38 of Set 9 | husavik
# Processing Record 39 of Set 9 | sitangkai
# Processing Record 40 of Set 9 | danjiangkou
# Processing Record 41 of Set 9 | amur
# Processing Record 42 of Set 9 | port townsend
# Processing Record 43 of Set 9 | luyang
# Processing Record 44 of Set 9 | porto nacional
# Processing Record 45 of Set 9 | puerto baquerizo moreno
# Processing Record 46 of Set 9 | porbandar
# Processing Record 47 of Set 9 | samarai
# Processing Record 48 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 9 | severo-kurilsk
# Processing Record 50 of Set 9 | otake
# Processing Record 1 of Set 10 | guhagar
# Processing Record 2 of Set 10 | soke
# Processing Record 3 of Set 10 | presque isle
# Processing Record 4 of Set 10 | noumea
# Processing Record 5 of Set 10 | muroto
# Processing Record 6 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 10 | ponta delgada
# Processing Record 8 of Set 10 | myre
# Processing Record 9 of Set 10 | auch
# Processing Record 10 of Set 10 | santarem
# Processing Record 11 of Set 10 | gladstone
# Processing Record 12 of Set 10 | shimoda
# Processing Record 13 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 10 | guerrero negro
# Processing Record 15 of Set 10 | yulara
# Processing Record 16 of Set 10 | kandrian
# Processing Record 17 of Set 10 | sur
# Processing Record 18 of Set 10 | salalah
# Processing Record 19 of Set 10 | leh
# Processing Record 20 of Set 10 | bangassou
# Processing Record 21 of Set 10 | gamba
# Processing Record 22 of Set 10 | melfi
# Processing Record 23 of Set 10 | pucara
# Processing Record 24 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 25 of Set 10 | altay
# Processing Record 26 of Set 10 | safranbolu
# Processing Record 27 of Set 10 | boyolangu
# Processing Record 28 of Set 10 | male
# Processing Record 29 of Set 10 | saryozek
# Processing Record 30 of Set 10 | onguday
# Processing Record 31 of Set 10 | la rioja
# Processing Record 32 of Set 10 | sambava
# Processing Record 33 of Set 10 | tabuny
# Processing Record 34 of Set 10 | bamiantong
# Processing Record 35 of Set 10 | vinh
# Processing Record 36 of Set 10 | talnakh
# Processing Record 37 of Set 10 | bac lieu
# Processing Record 38 of Set 10 | sola
# Processing Record 39 of Set 10 | shahreza
# Processing Record 40 of Set 10 | ilulissat
# Processing Record 41 of Set 10 | laela
# Processing Record 42 of Set 10 | vila velha
# Processing Record 43 of Set 10 | san patricio
# Processing Record 44 of Set 10 | kulhudhuffushi
# Processing Record 45 of Set 10 | vazhiny
# Processing Record 46 of Set 10 | mindelo
# Processing Record 47 of Set 10 | igrim
# Processing Record 48 of Set 10 | pitanga
# Processing Record 49 of Set 10 | port macquarie
# Processing Record 50 of Set 10 | huaiyuan
# Processing Record 1 of Set 11 | bowen
# Processing Record 2 of Set 11 | borba
# Processing Record 3 of Set 11 | nador
# Processing Record 4 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 11 | luwuk
# Processing Record 6 of Set 11 | bambanglipuro
# Processing Record 7 of Set 11 | valle de allende
# Processing Record 8 of Set 11 | leningradskiy
# Processing Record 9 of Set 11 | nha trang
# Processing Record 10 of Set 11 | bouake
# Processing Record 11 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 11 | port augusta
# Processing Record 14 of Set 11 | kampong thum
# Processing Record 15 of Set 11 | buchanan
# Processing Record 16 of Set 11 | zhangye
# Processing Record 17 of Set 11 | robat karim
# Processing Record 18 of Set 11 | hamilton
# Processing Record 19 of Set 11 | orange cove
# Processing Record 20 of Set 11 | san jeronimo
# Processing Record 21 of Set 11 | da nang
# Processing Record 22 of Set 11 | bairnsdale
# Processing Record 23 of Set 11 | college
# Processing Record 24 of Set 11 | indianola
# Processing Record 25 of Set 11 | puerto madero
# Processing Record 26 of Set 11 | karla
# Processing Record 27 of Set 11 | mareeba
# Processing Record 28 of Set 11 | yar-sale
# Processing Record 29 of Set 11 | half moon bay
# Processing Record 30 of Set 11 | altamont
# Processing Record 31 of Set 11 | deep river
# Processing Record 32 of Set 11 | mitsamiouli
# Processing Record 33 of Set 11 | angoche
# Processing Record 34 of Set 11 | vila do maio
# Processing Record 35 of Set 11 | taldan
# Processing Record 36 of Set 11 | duz
# City not found. Skipping...
# Processing Record 37 of Set 11 | laguna
# Processing Record 38 of Set 11 | sheridan
# Processing Record 39 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 40 of Set 11 | vestmanna
# Processing Record 41 of Set 11 | pisco
# Processing Record 42 of Set 11 | port hardy
# Processing Record 43 of Set 11 | paris
# Processing Record 44 of Set 11 | xining
# Processing Record 45 of Set 11 | mangrol
# Processing Record 46 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 47 of Set 11 | araioses
# Processing Record 48 of Set 11 | buala
# Processing Record 49 of Set 11 | sao francisco
# Processing Record 50 of Set 11 | tuatapere
# Processing Record 1 of Set 12 | mehran
# Processing Record 2 of Set 12 | ozinki
# Processing Record 3 of Set 12 | soe
# Processing Record 4 of Set 12 | tucuman
# Processing Record 5 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 12 | koungou
# Processing Record 8 of Set 12 | manadhoo
# Processing Record 9 of Set 12 | hovd
# Processing Record 10 of Set 12 | madimba
# Processing Record 11 of Set 12 | dudinka
# Processing Record 12 of Set 12 | zhaodong
# Processing Record 13 of Set 12 | emba
# Processing Record 14 of Set 12 | marakkanam
# Processing Record 15 of Set 12 | louga
# Processing Record 16 of Set 12 | moss vale
# Processing Record 17 of Set 12 | anjar
# Processing Record 18 of Set 12 | kutum
# Processing Record 19 of Set 12 | bulri
# Processing Record 20 of Set 12 | sumenep
# Processing Record 21 of Set 12 | gandia
# Processing Record 22 of Set 12 | yinchuan
# Processing Record 23 of Set 12 | superior
# Processing Record 24 of Set 12 | port moresby
# Processing Record 25 of Set 12 | teguise
# Processing Record 26 of Set 12 | belaya gora
# Processing Record 27 of Set 12 | zhigansk
# Processing Record 28 of Set 12 | adrar
# Processing Record 29 of Set 12 | banda aceh
# Processing Record 30 of Set 12 | almonte
# Processing Record 31 of Set 12 | monrovia
# Processing Record 32 of Set 12 | santa cruz cabralia
# Processing Record 33 of Set 12 | mezen
# Processing Record 34 of Set 12 | port lincoln
# Processing Record 35 of Set 12 | krasnoselkup
# Processing Record 36 of Set 12 | sjovegan
# Processing Record 37 of Set 12 | pau brasil
# Processing Record 38 of Set 12 | lahij
# Processing Record 39 of Set 12 | prince rupert
# Processing Record 40 of Set 12 | sinnamary
# Processing Record 41 of Set 12 | sakakah
# Processing Record 42 of Set 12 | araouane
# Processing Record 43 of Set 12 | xichang
# Processing Record 44 of Set 12 | awjilah
# Processing Record 45 of Set 12 | aykhal
# Processing Record 46 of Set 12 | muravlenko
# Processing Record 47 of Set 12 | znamenskoye
# Processing Record 48 of Set 12 | vangaindrano
# Processing Record 49 of Set 12 | zheleznodorozhnyy
# Processing Record 50 of Set 12 | mormugao
# Processing Record 1 of Set 13 | bonfim
# Processing Record 2 of Set 13 | nosy varika
# Processing Record 3 of Set 13 | aksu
# Processing Record 4 of Set 13 | stellenbosch
# Processing Record 5 of Set 13 | the valley
# Processing Record 6 of Set 13 | marsa matruh
# Processing Record 7 of Set 13 | bombay
# Processing Record 8 of Set 13 | sobolevo
# Processing Record 9 of Set 13 | geraldton
# Processing Record 10 of Set 13 | kavaratti
# Processing Record 11 of Set 13 | hazorasp
# Processing Record 12 of Set 13 | bundaberg
# Processing Record 13 of Set 13 | kashi
# Processing Record 14 of Set 13 | honiara
# Processing Record 15 of Set 13 | one hundred mile house
# City not found. Skipping...
# Processing Record 16 of Set 13 | vallenar
# Processing Record 17 of Set 13 | lambarene
# Processing Record 18 of Set 13 | kathmandu
# Processing Record 19 of Set 13 | soyo
# Processing Record 20 of Set 13 | tabou
# Processing Record 21 of Set 13 | gudiyattam
# City not found. Skipping...
# Processing Record 22 of Set 13 | tual
# Processing Record 23 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 13 | preobrazheniye
# Processing Record 25 of Set 13 | sigulda
# Processing Record 26 of Set 13 | gat
# Processing Record 27 of Set 13 | normandin
# Processing Record 28 of Set 13 | pak phanang
# Processing Record 29 of Set 13 | belem de sao francisco
# Processing Record 30 of Set 13 | guanica
# Processing Record 31 of Set 13 | andros town
# Processing Record 32 of Set 13 | marawi
# Processing Record 33 of Set 13 | neyyattinkara
# Processing Record 34 of Set 13 | vysokogornyy
# Processing Record 35 of Set 13 | dustlik
# Processing Record 36 of Set 13 | trapani
# Processing Record 37 of Set 13 | port hedland
# Processing Record 38 of Set 13 | lata
# Processing Record 39 of Set 13 | cayenne
# Processing Record 40 of Set 13 | hudson bay
# Processing Record 41 of Set 13 | mizan teferi
# Processing Record 42 of Set 13 | tazovskiy
# Processing Record 43 of Set 13 | bay roberts
# Processing Record 44 of Set 13 | alice springs
# Processing Record 45 of Set 13 | svetlogorsk
# Processing Record 46 of Set 13 | coruripe
# Processing Record 47 of Set 13 | kilifi
# Processing Record 48 of Set 13 | ola
# Processing Record 49 of Set 13 | norden
# Processing Record 50 of Set 13 | dobson
# Processing Record 1 of Set 14 | oussouye
# Processing Record 2 of Set 14 | kyra
# Processing Record 3 of Set 14 | san pedro
# Processing Record 4 of Set 14 | ketchikan
# Processing Record 5 of Set 14 | xuddur
# Processing Record 6 of Set 14 | banikoara
# Processing Record 7 of Set 14 | grantham
# Processing Record 8 of Set 14 | lincoln
# Processing Record 9 of Set 14 | ucluelet
# Processing Record 10 of Set 14 | paranga
# Processing Record 11 of Set 14 | porto novo
# Processing Record 12 of Set 14 | hohoe
# Processing Record 13 of Set 14 | velsk
# Processing Record 14 of Set 14 | baijiantan
# Processing Record 15 of Set 14 | upernavik
# Processing Record 16 of Set 14 | los algarrobos
# Processing Record 17 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 18 of Set 14 | sungairaya
# Processing Record 19 of Set 14 | juruti
# Processing Record 20 of Set 14 | ambilobe
# Processing Record 21 of Set 14 | itzehoe
# Processing Record 22 of Set 14 | darnah
# Processing Record 23 of Set 14 | santiago
# Processing Record 24 of Set 14 | jalu
# Processing Record 25 of Set 14 | glendive
# Processing Record 26 of Set 14 | ambon
# Processing Record 27 of Set 14 | nurota
# Processing Record 28 of Set 14 | vaitape
# Processing Record 29 of Set 14 | caapora
# Processing Record 30 of Set 14 | tukrah
# Processing Record 31 of Set 14 | chaplygin
# Processing Record 32 of Set 14 | kindu
# Processing Record 33 of Set 14 | okhotsk
# Processing Record 34 of Set 14 | det udom
# Processing Record 35 of Set 14 | kajaani
# Processing Record 36 of Set 14 | pinotepa nacional
# Processing Record 37 of Set 14 | forset
# City not found. Skipping...
# Processing Record 38 of Set 14 | tutoia
# Processing Record 39 of Set 14 | wenchi
# Processing Record 40 of Set 14 | molteno
# Processing Record 41 of Set 14 | joshimath
# Processing Record 42 of Set 14 | timberlake
# Processing Record 43 of Set 14 | aktau
# Processing Record 44 of Set 14 | mujiayingzi
# Processing Record 45 of Set 14 | hobyo
# Processing Record 46 of Set 14 | fomboni
# Processing Record 47 of Set 14 | tabatinga
# Processing Record 48 of Set 14 | alexandria
# Processing Record 49 of Set 14 | canto do buriti
# Processing Record 50 of Set 14 | bom jesus
# Processing Record 1 of Set 15 | vanimo
# Processing Record 2 of Set 15 | tomatlan
# Processing Record 3 of Set 15 | yuanping
# Processing Record 4 of Set 15 | caucasia
# Processing Record 5 of Set 15 | norman wells
# Processing Record 6 of Set 15 | bara
# Processing Record 7 of Set 15 | boca do acre
# Processing Record 8 of Set 15 | poronaysk
# Processing Record 9 of Set 15 | correntina
# Processing Record 10 of Set 15 | payo
# Processing Record 11 of Set 15 | caxito
# Processing Record 12 of Set 15 | hualmay
# Processing Record 13 of Set 15 | weligama
# Processing Record 14 of Set 15 | maragogi
# Processing Record 15 of Set 15 | colares
# Processing Record 16 of Set 15 | marica
# Processing Record 17 of Set 15 | inirida
# Processing Record 18 of Set 15 | marabba
# Processing Record 19 of Set 15 | hemsedal
# Processing Record 20 of Set 15 | kita
# Processing Record 21 of Set 15 | san angelo
# Processing Record 22 of Set 15 | havoysund
# Processing Record 23 of Set 15 | turbat
# Processing Record 24 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 15 | griffith
# Processing Record 26 of Set 15 | gushikawa
# Processing Record 27 of Set 15 | puerto ayacucho
# Processing Record 28 of Set 15 | ostrovnoy
# Processing Record 29 of Set 15 | merauke
# Processing Record 30 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 15 | dumka
# Processing Record 33 of Set 15 | kahului
# Processing Record 34 of Set 15 | yambio
# Processing Record 35 of Set 15 | celestun
# Processing Record 36 of Set 15 | grand gaube
# Processing Record 37 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 15 | paluan
# Processing Record 39 of Set 15 | huarmey
# Processing Record 40 of Set 15 | cacoal
# Processing Record 41 of Set 15 | santos dumont
# Processing Record 42 of Set 15 | westport
# Processing Record 43 of Set 15 | ibaiti
# Processing Record 44 of Set 15 | okato
# Processing Record 45 of Set 15 | terme
# Processing Record 46 of Set 15 | porto velho
# Processing Record 47 of Set 15 | san rafael del sur
# Processing Record 48 of Set 15 | matara
# Processing Record 49 of Set 15 | pacific grove
# Processing Record 50 of Set 15 | minas
# Processing Record 1 of Set 16 | rodino
# Processing Record 2 of Set 16 | ishigaki
# Processing Record 3 of Set 16 | tombouctou
# Processing Record 4 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 16 | mazyr
# Processing Record 6 of Set 16 | visnagar
# Processing Record 7 of Set 16 | tikrit
# Processing Record 8 of Set 16 | goderich
# Processing Record 9 of Set 16 | durusu
# Processing Record 10 of Set 16 | neryungri
# Processing Record 11 of Set 16 | yangambi
# Processing Record 12 of Set 16 | butembo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Cozumel  20.5083  -86.9458     77.07        92          90
# 1        Hermanus -34.4187   19.2345     59.90        67          40
# 2       Cape Town -33.9258   18.4232     62.28        70          20
# 3         Mataura -46.1927  168.8643     62.58        42          27
# 4         Qaanaaq  77.4840  -69.3632     -6.74        64          23
# 5          Atuona  -9.8000 -139.0333     78.33        70          24
# 6   Mar Del Plata -38.0023  -57.5575     62.62        88          40
# 7            Poum -20.2333  164.0167     77.50        79          94
# 8         Kinsale  51.7075   -8.5306     52.23       100          75
# 9  Saint-Philippe -21.3585   55.7679     73.22        70          53
#
#    Wind Speed Country                 Date
# 0        5.01      MX  2021-11-18 22:29:15
# 1        5.21      ZA  2021-11-18 22:29:15
# 2       14.97      ZA  2021-11-18 22:26:04
# 3        5.59      NZ  2021-11-18 22:29:16
# 4        7.49      GL  2021-11-18 22:29:16
# 5       11.12      PF  2021-11-18 22:25:58
# 6       15.99      AR  2021-11-18 22:25:33
# 7        6.15      NC  2021-11-18 22:29:17
# 8        6.91      IE  2021-11-18 22:29:17
# 9       12.17      RE  2021-11-18 22:29:17

# %%
column_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

# %%
city_data_df=city_data_df[column_order]

city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Cozumel      MX  2021-11-18 22:29:15  20.5083  -86.9458     77.07
# 1        Hermanus      ZA  2021-11-18 22:29:15 -34.4187   19.2345     59.90
# 2       Cape Town      ZA  2021-11-18 22:26:04 -33.9258   18.4232     62.28
# 3         Mataura      NZ  2021-11-18 22:29:16 -46.1927  168.8643     62.58
# 4         Qaanaaq      GL  2021-11-18 22:29:16  77.4840  -69.3632     -6.74
# 5          Atuona      PF  2021-11-18 22:25:58  -9.8000 -139.0333     78.33
# 6   Mar Del Plata      AR  2021-11-18 22:25:33 -38.0023  -57.5575     62.62
# 7            Poum      NC  2021-11-18 22:29:17 -20.2333  164.0167     77.50
# 8         Kinsale      IE  2021-11-18 22:29:17  51.7075   -8.5306     52.23
# 9  Saint-Philippe      RE  2021-11-18 22:29:17 -21.3585   55.7679     73.22
#
#    Humidity  Cloudiness  Wind Speed
# 0        92          90        5.01
# 1        67          40        5.21
# 2        70          20       14.97
# 3        42          27        5.59
# 4        64          23        7.49
# 5        70          24       11.12
# 6        88          40       15.99
# 7        79          94        6.15
# 8       100          75        6.91
# 9        70          53       12.17

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
